# %%
import os
import pandas as pd

filePath = "custom-data"

f2 = open("test2.csv","a")
f2.write("specie,Record Number,Process,Theory or Experiment,data type,Projectile Element,Projectile Charge State,\
Target Molecule,Target Charge State,Initial Excited State B,Products,Original X Unit,Original Y Unit,Reference Number,Author(s),\
Title of Record,Journal Name,Volume and Issue No,Page Numbers,Date of Publication,Process Title\n")

for files in os.listdir(filePath):
    for file in os.listdir("{}/{}".format(filePath,files)):
        with open("{}/{}/{}".format(filePath,files,file)) as f:
            lines = f.readlines()       
            f2.write("{},".format(files))
            print(lines)
            for line in lines:
                print(line)
                f2.write(line.split(" =")[1].replace("\n","").replace(",","###"))
                f2.write(",")
            f2.write("\n")
f2.close()
# Out:
# ['Record Number = 11624\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 13C\n', 'Projectile Charge State = 3\n', 'Target Molecule = H2O\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 13C2+;H2O+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 13C3+ + H2O --> 13C2++H2O+']
# Record Number = 11624
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 13C
#
# Projectile Charge State = 3
#
# Target Molecule = H2O
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 13C2+;H2O+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 13C3+ + H2O --> 13C2++H2O+
# ['Record Number = 11625\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 13C\n', 'Projectile Charge State = 3\n', 'Target Molecule = H2O\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 13C+;H2O2+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 13C3+ + H2O --> 13C++H2O2+']
# Record Number = 11625
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 13C
#
# Projectile Charge State = 3
#
# Target Molecule = H2O
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 13C+;H2O2+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 13C3+ + H2O --> 13C++H2O2+
# ['Record Number = 11626\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 13C\n', 'Projectile Charge State = 3\n', 'Target Molecule = CO2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 13C2+;CO2+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 13C3+ + CO2 --> 13C2++CO2+']
# Record Number = 11626
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 13C
#
# Projectile Charge State = 3
#
# Target Molecule = CO2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 13C2+;CO2+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 13C3+ + CO2 --> 13C2++CO2+
# ['Record Number = 11627\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 13C\n', 'Projectile Charge State = 3\n', 'Target Molecule = CO2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 13C+;CO22+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 13C3+ + CO2 --> 13C++CO22+']
# Record Number = 11627
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 13C
#
# Projectile Charge State = 3
#
# Target Molecule = CO2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 13C+;CO22+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 13C3+ + CO2 --> 13C++CO22+
# ['Record Number = 11628\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 13C\n', 'Projectile Charge State = 3\n', 'Target Molecule = H2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 13C2+;H2+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 13C3+ + H2 --> 13C2++H2+']
# Record Number = 11628
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 13C
#
# Projectile Charge State = 3
#
# Target Molecule = H2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 13C2+;H2+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 13C3+ + H2 --> 13C2++H2+
# ['Record Number = 11629\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 13C\n', 'Projectile Charge State = 3\n', 'Target Molecule = H2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 13C+;H22+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 13C3+ + H2 --> 13C++H22+']
# Record Number = 11629
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 13C
#
# Projectile Charge State = 3
#
# Target Molecule = H2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 13C+;H22+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 13C3+ + H2 --> 13C++H22+
# ['Record Number = 11630\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 13C\n', 'Projectile Charge State = 6\n', 'Target Molecule = H2O\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 13C5+;H2O+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 13C6+ + H2O --> 13C5++H2O+']
# Record Number = 11630
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 13C
#
# Projectile Charge State = 6
#
# Target Molecule = H2O
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 13C5+;H2O+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 13C6+ + H2O --> 13C5++H2O+
# ['Record Number = 11631\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 13C\n', 'Projectile Charge State = 6\n', 'Target Molecule = H2O\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 13C4+;H2O2+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 13C6+ + H2O --> 13C4++H2O2+']
# Record Number = 11631
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 13C
#
# Projectile Charge State = 6
#
# Target Molecule = H2O
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 13C4+;H2O2+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 13C6+ + H2O --> 13C4++H2O2+
# ['Record Number = 11632\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 13C\n', 'Projectile Charge State = 6\n', 'Target Molecule = CO2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 13C5+;CO2+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 13C6+ + CO2 --> 13C5++CO2+']
# Record Number = 11632
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 13C
#
# Projectile Charge State = 6
#
# Target Molecule = CO2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 13C5+;CO2+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 13C6+ + CO2 --> 13C5++CO2+
# ['Record Number = 11633\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 13C\n', 'Projectile Charge State = 6\n', 'Target Molecule = CO2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 13C4+;CO22+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 13C6+ + CO2 --> 13C4++CO22+']
# Record Number = 11633
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 13C
#
# Projectile Charge State = 6
#
# Target Molecule = CO2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 13C4+;CO22+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 13C6+ + CO2 --> 13C4++CO22+
# ['Record Number = 11634\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 13C\n', 'Projectile Charge State = 6\n', 'Target Molecule = H2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 13C5+;H2+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 13C6+ + H2 --> 13C5++H2+']
# Record Number = 11634
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 13C
#
# Projectile Charge State = 6
#
# Target Molecule = H2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 13C5+;H2+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 13C6+ + H2 --> 13C5++H2+
# ['Record Number = 11635\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 15N\n', 'Projectile Charge State = 4\n', 'Target Molecule = H2O\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 15N3+;H2O+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 15N4+ + H2O --> 15N3++H2O+']
# Record Number = 11635
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 15N
#
# Projectile Charge State = 4
#
# Target Molecule = H2O
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 15N3+;H2O+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 15N4+ + H2O --> 15N3++H2O+
# ['Record Number = 11636\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 15N\n', 'Projectile Charge State = 4\n', 'Target Molecule = H2O\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 15N2+;H2O+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 15N4+ + H2O --> 15N2++H2O+']
# Record Number = 11636
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 15N
#
# Projectile Charge State = 4
#
# Target Molecule = H2O
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 15N2+;H2O+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 15N4+ + H2O --> 15N2++H2O+
# ['Record Number = 11637\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 15N\n', 'Projectile Charge State = 4\n', 'Target Molecule = CO2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 15N3+;CO2+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 15N4+ + CO2 --> 15N3++CO2+']
# Record Number = 11637
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 15N
#
# Projectile Charge State = 4
#
# Target Molecule = CO2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 15N3+;CO2+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 15N4+ + CO2 --> 15N3++CO2+
# ['Record Number = 11638\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 15N\n', 'Projectile Charge State = 4\n', 'Target Molecule = CO2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 15N2+;CO22+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 15N4+ + CO2 --> 15N2++CO22+']
# Record Number = 11638
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 15N
#
# Projectile Charge State = 4
#
# Target Molecule = CO2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 15N2+;CO22+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 15N4+ + CO2 --> 15N2++CO22+
# ['Record Number = 11639\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 15N\n', 'Projectile Charge State = 4\n', 'Target Molecule = H2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 15N3+;H2+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 15N4+ + H2 --> 15N3++H2+']
# Record Number = 11639
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 15N
#
# Projectile Charge State = 4
#
# Target Molecule = H2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 15N3+;H2+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 15N4+ + H2 --> 15N3++H2+
# ['Record Number = 11640\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 15N\n', 'Projectile Charge State = 4\n', 'Target Molecule = H2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 15N2+;H22+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 15N4+ + H2 --> 15N2++H22+']
# Record Number = 11640
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 15N
#
# Projectile Charge State = 4
#
# Target Molecule = H2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 15N2+;H22+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 15N4+ + H2 --> 15N2++H22+
# ['Record Number = 11641\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 15N\n', 'Projectile Charge State = 7\n', 'Target Molecule = H2O\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 15N6+;H2O+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 15N7+ + H2O --> 15N6++H2O+']
# Record Number = 11641
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 15N
#
# Projectile Charge State = 7
#
# Target Molecule = H2O
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 15N6+;H2O+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 15N7+ + H2O --> 15N6++H2O+
# ['Record Number = 11642\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 15N\n', 'Projectile Charge State = 7\n', 'Target Molecule = H2O\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 15N5+;H2O2+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 15N7+ + H2O --> 15N5++H2O2+']
# Record Number = 11642
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 15N
#
# Projectile Charge State = 7
#
# Target Molecule = H2O
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 15N5+;H2O2+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 15N7+ + H2O --> 15N5++H2O2+
# ['Record Number = 11643\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 15N\n', 'Projectile Charge State = 7\n', 'Target Molecule = CO2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 15N6+;CO2+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 15N7+ + CO2 --> 15N6++CO2+']
# Record Number = 11643
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 15N
#
# Projectile Charge State = 7
#
# Target Molecule = CO2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 15N6+;CO2+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 15N7+ + CO2 --> 15N6++CO2+
# ['Record Number = 11644\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 15N\n', 'Projectile Charge State = 7\n', 'Target Molecule = CO2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 15N5+;CO22+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 15N7+ + CO2 --> 15N5++CO22+']
# Record Number = 11644
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 15N
#
# Projectile Charge State = 7
#
# Target Molecule = CO2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 15N5+;CO22+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 15N7+ + CO2 --> 15N5++CO22+
# ['Record Number = 11645\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 15N\n', 'Projectile Charge State = 7\n', 'Target Molecule = H2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 15N6+;H2+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 15N7+ + H2 --> 15N6++H2+']
# Record Number = 11645
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 15N
#
# Projectile Charge State = 7
#
# Target Molecule = H2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 15N6+;H2+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 15N7+ + H2 --> 15N6++H2+
# ['Record Number = 11646\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 16O\n', 'Projectile Charge State = 5\n', 'Target Molecule = H2O\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 16O4+;H2O+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 16O5+ + H2O --> 16O4++H2O+']
# Record Number = 11646
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 16O
#
# Projectile Charge State = 5
#
# Target Molecule = H2O
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 16O4+;H2O+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 16O5+ + H2O --> 16O4++H2O+
# ['Record Number = 11647\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 16O\n', 'Projectile Charge State = 5\n', 'Target Molecule = H2O\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 16O3+;H2O2+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 16O5+ + H2O --> 16O3++H2O2+']
# Record Number = 11647
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 16O
#
# Projectile Charge State = 5
#
# Target Molecule = H2O
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 16O3+;H2O2+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 16O5+ + H2O --> 16O3++H2O2+
# ['Record Number = 11648\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 16O\n', 'Projectile Charge State = 5\n', 'Target Molecule = CO2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 16O4+;CO2+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 16O5+ + CO2 --> 16O4++CO2+']
# Record Number = 11648
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 16O
#
# Projectile Charge State = 5
#
# Target Molecule = CO2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 16O4+;CO2+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 16O5+ + CO2 --> 16O4++CO2+
# ['Record Number = 11649\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 16O\n', 'Projectile Charge State = 5\n', 'Target Molecule = CO2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 16O3+;CO22+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 16O5+ + CO2 --> 16O3++CO22+']
# Record Number = 11649
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 16O
#
# Projectile Charge State = 5
#
# Target Molecule = CO2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 16O3+;CO22+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 16O5+ + CO2 --> 16O3++CO22+
# ['Record Number = 11650\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 16O\n', 'Projectile Charge State = 5\n', 'Target Molecule = CO2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 16O2+;CO23+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 16O5+ + CO2 --> 16O2++CO23+']
# Record Number = 11650
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 16O
#
# Projectile Charge State = 5
#
# Target Molecule = CO2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 16O2+;CO23+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 16O5+ + CO2 --> 16O2++CO23+
# ['Record Number = 11651\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 16O\n', 'Projectile Charge State = 5\n', 'Target Molecule = H2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 16O4+;H2+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 16O5+ + H2 --> 16O4++H2+']
# Record Number = 11651
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 16O
#
# Projectile Charge State = 5
#
# Target Molecule = H2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 16O4+;H2+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 16O5+ + H2 --> 16O4++H2+
# ['Record Number = 11652\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 18O\n', 'Projectile Charge State = 7\n', 'Target Molecule = H2O\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 18O6+;H2O+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 18O7+ + H2O --> 18O6++H2O+']
# Record Number = 11652
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 18O
#
# Projectile Charge State = 7
#
# Target Molecule = H2O
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 18O6+;H2O+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 18O7+ + H2O --> 18O6++H2O+
# ['Record Number = 11653\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 18O\n', 'Projectile Charge State = 7\n', 'Target Molecule = H2O\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 18O5+;H2O2+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 18O7+ + H2O --> 18O5++H2O2+']
# Record Number = 11653
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 18O
#
# Projectile Charge State = 7
#
# Target Molecule = H2O
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 18O5+;H2O2+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 18O7+ + H2O --> 18O5++H2O2+
# ['Record Number = 11654\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 18O\n', 'Projectile Charge State = 7\n', 'Target Molecule = CO2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 18O6+;CO2+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 18O7+ + CO2 --> 18O6++CO2+']
# Record Number = 11654
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 18O
#
# Projectile Charge State = 7
#
# Target Molecule = CO2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 18O6+;CO2+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 18O7+ + CO2 --> 18O6++CO2+
# ['Record Number = 11655\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 18O\n', 'Projectile Charge State = 7\n', 'Target Molecule = CO2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 18O5+;CO22+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 18O7+ + CO2 --> 18O5++CO22+']
# Record Number = 11655
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 18O
#
# Projectile Charge State = 7
#
# Target Molecule = CO2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 18O5+;CO22+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 18O7+ + CO2 --> 18O5++CO22+
# ['Record Number = 11656\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 18O\n', 'Projectile Charge State = 7\n', 'Target Molecule = CO2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 18O4+;CO23+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 18O7+ + CO2 --> 18O4++CO23+']
# Record Number = 11656
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 18O
#
# Projectile Charge State = 7
#
# Target Molecule = CO2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 18O4+;CO23+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2001E304
#
# Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.
#
# Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 63
#
# Page Numbers = 062707
#
# Date of Publication = 2001
#
# Process Title = 18O7+ + CO2 --> 18O4++CO23+
# ['Record Number = 11657\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = 18O\n', 'Projectile Charge State = 7\n', 'Target Molecule = H2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = 18O6+;H2+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2001E304\n', 'Author(s) = Greenwood, J.B.$Williams, I.D.$Smith, S.J.$Chutjian, A.\n', 'Title of Record = Experimental investigation of the processes determining x-ray emission intensities from charge-exchange collisions\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 63\n', 'Page Numbers = 062707\n', 'Date of Publication = 2001\n', 'Process Title = 18O7+ + H2 --> 18O6++H2+']
# Record Number = 11657
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = 18O
#
# Projectile Charge State = 7
#
# Target Molecule = H2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = 18O6+;H2+
#
# Original X Unit = eV
#
# ...
# Record Number = 11622
#
# Process = charge transfer
#
# Theory or Experiment = T
#
# data type = CS
#
# Projectile Element = O
#
# Projectile Charge State = +1
#
# Target Molecule = H2
#
# Target Charge State = 0
#
# Initial Excited State B = 0
#
# Products = O;H2+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2004C437
#
# Author(s) = Pichl,L.$Li,Y.$Liebermann,H.-P.$Buenker,R.J.$Kimura,M.
#
# Title of Record = Electron capture and excitation in collisions of O+(4S, 2D, 2P) with H2 molecules
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 69
#
# Page Numbers = 062715
#
# Date of Publication = 2004
#
# Process Title = O+ (4S) + H2 (0) --> O+H2+
# ['Record Number = 11623\n', 'Process = charge transfer\n', 'Theory or Experiment = T\n', 'data type = CS\n', 'Projectile Element = O\n', 'Projectile Charge State = +3\n', 'Target Molecule = H2\n', 'Target Charge State = 0\n', 'Initial Excited State B = 0\n', 'Products = O2+;H2+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2004C438\n', 'Author(s) = Wang,J.G.$Stancil,P.C.$Turner,A.-R.$Cooper,L.D.\n', 'Title of Record = Electron capture and excitation in collisions of O+(4S, 2D, 2P) with H2 molecules\n', 'Journal Name = Phys. Rev. A\n', 'Volume and Issue No. = 69\n', 'Page Numbers = 062702\n', 'Date of Publication = 2004\n', 'Process Title = O3+ (2P) + H2 (0) --> O2++H2+']
# Record Number = 11623
#
# Process = charge transfer
#
# Theory or Experiment = T
#
# data type = CS
#
# Projectile Element = O
#
# Projectile Charge State = +3
#
# Target Molecule = H2
#
# Target Charge State = 0
#
# Initial Excited State B = 0
#
# Products = O2+;H2+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2004C438
#
# Author(s) = Wang,J.G.$Stancil,P.C.$Turner,A.-R.$Cooper,L.D.
#
# Title of Record = Electron capture and excitation in collisions of O+(4S, 2D, 2P) with H2 molecules
#
# Journal Name = Phys. Rev. A
#
# Volume and Issue No. = 69
#
# Page Numbers = 062702
#
# Date of Publication = 2004
#
# Process Title = O3+ (2P) + H2 (0) --> O2++H2+
# ['Record Number = 12128\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = Si\n', 'Projectile Charge State = +7\n', 'Target Molecule = H2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = Si6+;H2+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2018E301\n', 'Author(s) = Moradmand, A.$El Ghazaly, M.O.A.$Mahaptra, D.P.$A. Chutjian\n', 'Title of Record = Measurement of Absolute Single and Double Charge Exchange Cross Sections for Si(7-10)+ at 0.88-2.50 KeV/u Impacting He and H2\n', 'Journal Name =\n', 'Volume and Issue No. = 234\n', 'Page Numbers = 14\n', 'Date of Publication = 2018\n', 'Process Title = Si7+ + H2 --> Si6++H2+']
# Record Number = 12128
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = Si
#
# Projectile Charge State = +7
#
# Target Molecule = H2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = Si6+;H2+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2018E301
#
# Author(s) = Moradmand, A.$El Ghazaly, M.O.A.$Mahaptra, D.P.$A. Chutjian
#
# Title of Record = Measurement of Absolute Single and Double Charge Exchange Cross Sections for Si(7-10)+ at 0.88-2.50 KeV/u Impacting He and H2
#
# Journal Name =
#
# Volume and Issue No. = 234
#
# Page Numbers = 14
#
# Date of Publication = 2018
#
# Process Title = Si7+ + H2 --> Si6++H2+
# ['Record Number = 12129\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = Si\n', 'Projectile Charge State = +8\n', 'Target Molecule = H2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = Si6+;H2+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2018E301\n', 'Author(s) = Moradmand, A.$El Ghazaly, M.O.A.$Mahaptra, D.P.$A. Chutjian\n', 'Title of Record = Measurement of Absolute Single and Double Charge Exchange Cross Sections for Si(7-10)+ at 0.88-2.50 KeV/u Impacting He and H2\n', 'Journal Name =\n', 'Volume and Issue No. = 234\n', 'Page Numbers = 14\n', 'Date of Publication = 2018\n', 'Process Title = Si8+ + H2 --> Si6++H2+']
# Record Number = 12129
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = Si
#
# Projectile Charge State = +8
#
# Target Molecule = H2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = Si6+;H2+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2018E301
#
# Author(s) = Moradmand, A.$El Ghazaly, M.O.A.$Mahaptra, D.P.$A. Chutjian
#
# Title of Record = Measurement of Absolute Single and Double Charge Exchange Cross Sections for Si(7-10)+ at 0.88-2.50 KeV/u Impacting He and H2
#
# Journal Name =
#
# Volume and Issue No. = 234
#
# Page Numbers = 14
#
# Date of Publication = 2018
#
# Process Title = Si8+ + H2 --> Si6++H2+
# ['Record Number = 12130\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = Si\n', 'Projectile Charge State = +9\n', 'Target Molecule = H2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = Si6+;H2+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2018E301\n', 'Author(s) = Moradmand, A.$El Ghazaly, M.O.A.$Mahaptra, D.P.$A. Chutjian\n', 'Title of Record = Measurement of Absolute Single and Double Charge Exchange Cross Sections for Si(7-10)+ at 0.88-2.50 KeV/u Impacting He and H2\n', 'Journal Name =\n', 'Volume and Issue No. = 234\n', 'Page Numbers = 14\n', 'Date of Publication = 2018\n', 'Process Title = Si9+ + H2 --> Si6++H2+']
# Record Number = 12130
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = Si
#
# Projectile Charge State = +9
#
# Target Molecule = H2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = Si6+;H2+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2018E301
#
# Author(s) = Moradmand, A.$El Ghazaly, M.O.A.$Mahaptra, D.P.$A. Chutjian
#
# Title of Record = Measurement of Absolute Single and Double Charge Exchange Cross Sections for Si(7-10)+ at 0.88-2.50 KeV/u Impacting He and H2
#
# Journal Name =
#
# Volume and Issue No. = 234
#
# Page Numbers = 14
#
# Date of Publication = 2018
#
# Process Title = Si9+ + H2 --> Si6++H2+
# ['Record Number = 12131\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = Si\n', 'Projectile Charge State = +10\n', 'Target Molecule = H2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = Si6+;H2+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2018E301\n', 'Author(s) = Moradmand, A.$El Ghazaly, M.O.A.$Mahaptra, D.P.$A. Chutjian\n', 'Title of Record = Measurement of Absolute Single and Double Charge Exchange Cross Sections for Si(7-10)+ at 0.88-2.50 KeV/u Impacting He and H2\n', 'Journal Name =\n', 'Volume and Issue No. = 234\n', 'Page Numbers = 14\n', 'Date of Publication = 2018\n', 'Process Title = Si10+ + H2 --> Si6++H2+']
# Record Number = 12131
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = Si
#
# Projectile Charge State = +10
#
# Target Molecule = H2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = Si6+;H2+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2018E301
#
# Author(s) = Moradmand, A.$El Ghazaly, M.O.A.$Mahaptra, D.P.$A. Chutjian
#
# Title of Record = Measurement of Absolute Single and Double Charge Exchange Cross Sections for Si(7-10)+ at 0.88-2.50 KeV/u Impacting He and H2
#
# Journal Name =
#
# Volume and Issue No. = 234
#
# Page Numbers = 14
#
# Date of Publication = 2018
#
# Process Title = Si10+ + H2 --> Si6++H2+
# ['Record Number = 12132\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = Si\n', 'Projectile Charge State = +7\n', 'Target Molecule = H2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = Si5+;H22+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2018E301\n', 'Author(s) = Moradmand, A.$El Ghazaly, M.O.A.$Mahaptra, D.P.$A. Chutjian\n', 'Title of Record = Measurement of Absolute Single and Double Charge Exchange Cross Sections for Si(7-10)+ at 0.88-2.50 KeV/u Impacting He and H2\n', 'Journal Name =\n', 'Volume and Issue No. = 234\n', 'Page Numbers = 14\n', 'Date of Publication = 2018\n', 'Process Title = Si7+ + H2 --> Si5++H22+']
# Record Number = 12132
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = Si
#
# Projectile Charge State = +7
#
# Target Molecule = H2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = Si5+;H22+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2018E301
#
# Author(s) = Moradmand, A.$El Ghazaly, M.O.A.$Mahaptra, D.P.$A. Chutjian
#
# Title of Record = Measurement of Absolute Single and Double Charge Exchange Cross Sections for Si(7-10)+ at 0.88-2.50 KeV/u Impacting He and H2
#
# Journal Name =
#
# Volume and Issue No. = 234
#
# Page Numbers = 14
#
# Date of Publication = 2018
#
# Process Title = Si7+ + H2 --> Si5++H22+
# ['Record Number = 12133\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = Si\n', 'Projectile Charge State = +8\n', 'Target Molecule = H2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = Si5+;H22+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2018E301\n', 'Author(s) = Moradmand, A.$El Ghazaly, M.O.A.$Mahaptra, D.P.$A. Chutjian\n', 'Title of Record = Measurement of Absolute Single and Double Charge Exchange Cross Sections for Si(7-10)+ at 0.88-2.50 KeV/u Impacting He and H2\n', 'Journal Name =\n', 'Volume and Issue No. = 234\n', 'Page Numbers = 14\n', 'Date of Publication = 2018\n', 'Process Title = Si8+ + H2 --> Si5++H22+']
# Record Number = 12133
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = Si
#
# Projectile Charge State = +8
#
# Target Molecule = H2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = Si5+;H22+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2018E301
#
# Author(s) = Moradmand, A.$El Ghazaly, M.O.A.$Mahaptra, D.P.$A. Chutjian
#
# Title of Record = Measurement of Absolute Single and Double Charge Exchange Cross Sections for Si(7-10)+ at 0.88-2.50 KeV/u Impacting He and H2
#
# Journal Name =
#
# Volume and Issue No. = 234
#
# Page Numbers = 14
#
# Date of Publication = 2018
#
# Process Title = Si8+ + H2 --> Si5++H22+
# ['Record Number = 12134\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = Si\n', 'Projectile Charge State = +9\n', 'Target Molecule = H2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = Si5+;H22+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2018E301\n', 'Author(s) = Moradmand, A.$El Ghazaly, M.O.A.$Mahaptra, D.P.$A. Chutjian\n', 'Title of Record = Measurement of Absolute Single and Double Charge Exchange Cross Sections for Si(7-10)+ at 0.88-2.50 KeV/u Impacting He and H2\n', 'Journal Name =\n', 'Volume and Issue No. = 234\n', 'Page Numbers = 14\n', 'Date of Publication = 2018\n', 'Process Title = Si9+ + H2 --> Si5++H22+']
# Record Number = 12134
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = Si
#
# Projectile Charge State = +9
#
# Target Molecule = H2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = Si5+;H22+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2018E301
#
# Author(s) = Moradmand, A.$El Ghazaly, M.O.A.$Mahaptra, D.P.$A. Chutjian
#
# Title of Record = Measurement of Absolute Single and Double Charge Exchange Cross Sections for Si(7-10)+ at 0.88-2.50 KeV/u Impacting He and H2
#
# Journal Name =
#
# Volume and Issue No. = 234
#
# Page Numbers = 14
#
# Date of Publication = 2018
#
# Process Title = Si9+ + H2 --> Si5++H22+
# ['Record Number = 12135\n', 'Process = charge exchange\n', 'Theory or Experiment = E\n', 'data type = CS\n', 'Projectile Element = Si\n', 'Projectile Charge State = +10\n', 'Target Molecule = H2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = Si5+;H22+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2018E301\n', 'Author(s) = Moradmand, A.$El Ghazaly, M.O.A.$Mahaptra, D.P.$A. Chutjian\n', 'Title of Record = Measurement of Absolute Single and Double Charge Exchange Cross Sections for Si(7-10)+ at 0.88-2.50 KeV/u Impacting He and H2\n', 'Journal Name =\n', 'Volume and Issue No. = 234\n', 'Page Numbers = 14\n', 'Date of Publication = 2018\n', 'Process Title = Si10+ + H2 --> Si5++H22+']
# Record Number = 12135
#
# Process = charge exchange
#
# Theory or Experiment = E
#
# data type = CS
#
# Projectile Element = Si
#
# Projectile Charge State = +10
#
# Target Molecule = H2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = Si5+;H22+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2018E301
#
# Author(s) = Moradmand, A.$El Ghazaly, M.O.A.$Mahaptra, D.P.$A. Chutjian
#
# Title of Record = Measurement of Absolute Single and Double Charge Exchange Cross Sections for Si(7-10)+ at 0.88-2.50 KeV/u Impacting He and H2
#
# Journal Name =
#
# Volume and Issue No. = 234
#
# Page Numbers = 14
#
# Date of Publication = 2018
#
# Process Title = Si10+ + H2 --> Si5++H22+
# ['Record Number = 10345\n', 'Process = charge transfer\n', 'Theory or Experiment = T\n', 'data type = CS\n', 'Projectile Element = T\n', 'Projectile Charge State = +1\n', 'Target Molecule = T2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = T;T2+\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2000T302\n', 'Author(s) = Ichihara, A.$Iwamoto, O.$Janev, R.K.\n', 'Title of Record = Cross sections for the reaction H+ + H2 (v = 0-14) -> H + H2+ at low collision energies\n', 'Journal Name = J. Phys. B\n', 'Volume and Issue No. = 33\n', 'Page Numbers = 4747-4758\n', 'Date of Publication = 2000\n', 'Process Title = T+ (v=9,j=1) + T2 --> T+T2+']
# Record Number = 10345
#
# Process = charge transfer
#
# Theory or Experiment = T
#
# data type = CS
#
# Projectile Element = T
#
# Projectile Charge State = +1
#
# Target Molecule = T2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = T;T2+
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2000T302
#
# Author(s) = Ichihara, A.$Iwamoto, O.$Janev, R.K.
#
# Title of Record = Cross sections for the reaction H+ + H2 (v = 0-14) -> H + H2+ at low collision energies
#
# Journal Name = J. Phys. B
#
# Volume and Issue No. = 33
#
# Page Numbers = 4747-4758
#
# Date of Publication = 2000
#
# Process Title = T+ (v=9,j=1) + T2 --> T+T2+
# ['Record Number = 10406\n', 'Process = dissociation\n', 'Theory or Experiment = T\n', 'data type = CS\n', 'Projectile Element = T\n', 'Projectile Charge State = +1\n', 'Target Molecule = T2\n', 'Target Charge State = 0\n', 'Initial Excited State B =\n', 'Products = T+;T;T\n', 'Original X Unit = eV\n', 'Original Y Unit = cm2\n', 'Reference Number = 2000T303\n', 'Author(s) = Ichihara, A.\n', 'Title of Record =\n', 'Journal Name = Private Communication\n', 'Volume and Issue No. =\n', 'Page Numbers =\n', 'Date of Publication = 2000\n', 'Process Title = T+ (v=9,j=1) + T2 --> T++T+T']
# Record Number = 10406
#
# Process = dissociation
#
# Theory or Experiment = T
#
# data type = CS
#
# Projectile Element = T
#
# Projectile Charge State = +1
#
# Target Molecule = T2
#
# Target Charge State = 0
#
# Initial Excited State B =
#
# Products = T+;T;T
#
# Original X Unit = eV
#
# Original Y Unit = cm2
#
# Reference Number = 2000T303
#
# Author(s) = Ichihara, A.
#
# Title of Record =
#
# Journal Name = Private Communication
#
# Volume and Issue No. =
#
# Page Numbers =
#
# Date of Publication = 2000
#
# Process Title = T+ (v=9,j=1) + T2 --> T++T+T
